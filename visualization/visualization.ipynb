# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
plt.rcParams.update({'font.size': 20})
plt.rcParams.update({'lines.linewidth': 2})

# %% [markdown]
# ### RandClif

# %%
plt.rcParams["figure.figsize"] = (6,5)
range_l = 68 + np.array([1,2,4,8])
for i in range_l:
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3)
    plt.scatter([20],[2*(i-68)])

plt.xlim([0,20])
plt.ylim([1e-3,3e1])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(69,78):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3)
    plt.scatter([20],[2*(i-68)])

plt.xlim([0,20])
plt.ylim([1e-3,3e1])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(132,151):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3)
    # plt.scatter([40],[2*(i-131)])

plt.xlim([0,40])
plt.ylim([1e-3,40])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
plt.yscale('log')
plt.tight_layout()
# Out:
# Error in callback <function flush_figures at 0x11600d700> (for post_execute):
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/PIL/ImageFile.py:495, in _save(im, fp, tile, bufsize)
#     494 try:
# --> 495     fh = fp.fileno()
#     496     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:121, in flush_figures()
#     118 if InlineBackend.instance().close_figures:
#     119     # ignore the tracking, just draw and close all figures
#     120     try:
# --> 121         return show(True)
#     122     except Exception as e:
# ...

# %%
plt.rcParams["figure.figsize"] = (3,5)

for i in range(69,78):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3)
    plt.scatter([19.97],[2*(i-68)])

plt.xlim([19,20])
plt.ylim([5e-1,3e1])
# plt.xlabel("number of measurements")
# plt.ylabel("MIE")
plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(132,151):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3)
    # plt.scatter([40],[2*(i-131)])

plt.xlim([0,40])
plt.ylim([1e-3,40])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
# plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(18,23):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3,'b')
    raw = np.loadtxt("data/230213/230213_%d"%(i-16),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3,'m')
    raw = np.loadtxt("data/230213/230213_%d"%(i-18+59),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3,'g')
    raw = np.loadtxt("data/230213/230213_%d"%(i-18+64),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3,'y')

plt.xlim([0,100])
plt.ylim([1e-2,2e1])
plt.xticks([0,20,40,60,80,100])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(18,23):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]/2+1e-3,'b')
    raw = np.loadtxt("data/230213/230213_%d"%(i-16),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]/1+1e-3,'m')
    raw = np.loadtxt("data/230213/230213_%d"%(i-18+59),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]/4+1e-3,'g')
    raw = np.loadtxt("data/230213/230213_%d"%(i-18+64),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]/8+1e-3,'y')

plt.xlim([0,100])
plt.ylim([1e-2,2])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
plt.yscale('log')
plt.tight_layout()

# %% [markdown]
# ### RandHPB

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(23,28):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3)
    # plt.scatter([20],[2*(i-6)])

plt.xlim([0,100])
plt.ylim([1e-1,5])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(28,33):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3)
    # plt.scatter([20],[2*(i-6)])

plt.xlim([0,100])
plt.ylim([1e-1,5])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(33,38):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[0::2,0],raw[0::2,1]+1e-3)
    # plt.scatter([20],[2*(i-6)])

plt.xlim([0,10])
# plt.ylim([1e-1,5])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
# plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(79,84):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[0::2,0],raw[0::2,1]+1e-3)
    # plt.scatter([20],[2*(i-6)])

plt.xlim([0,20])
plt.ylim([0,2.2])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
# plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(84,93):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[0:,1]+1e-3)
    # plt.scatter([20],[2*(i-6)])

# plt.xlim([0,20])
# plt.ylim([0,2.2])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
# plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(94,103):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[0:,1]+1e-3)
    plt.scatter([40],[2*(i-93)])

plt.xlim([0,40])
plt.ylim([0,20])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
# plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (3,5)

for i in range(94,103):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[0:,1]+1e-3)
    plt.scatter([39.98],[2*(i-93)])

plt.xlim([39,40])
plt.ylim([0,20])
# plt.xlabel("number of measurements")
# plt.ylabel("MIE")
# plt.yscale('log')
plt.tight_layout()

# %% [markdown]
# ### RandHP

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(104,112):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[1:,0],raw[1:,1]+1e-3)
    # plt.scatter([20],[2*(i-6)])

plt.xlim([0,50])
plt.ylim([0,2.2])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
# plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(112,132):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3)
    # plt.scatter([40],[2*(i-111)])

plt.xlim([0,40])
plt.ylim([1e-3,22])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
# plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(162,172):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3)
    # plt.scatter([40],[2*(i-111)])


# for i in range(182,192):
#     raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
#     plt.plot(raw[:,0],raw[:,1]+1e-3)

plt.xlim([0,40])
plt.ylim([1e-3,22])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
# plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)

# for i in range(162,172):
#     raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
#     plt.plot(raw[:,0],raw[:,1]+1e-3)
#     # plt.scatter([40],[2*(i-111)])


for i in range(182,192):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3)

plt.xlim([0,40])
plt.ylim([1e-3,22])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
# plt.yscale('log')
plt.tight_layout()

# %% [markdown]
# ### randHP_2CLlif

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(49,54):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[1:,0],raw[1:,1]+1e-3)
    # plt.scatter([20],[2*(i-6)])

# plt.xlim([0,10])
# plt.ylim([1e-1,5])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(54,59):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[1:,0],raw[1:,1]+1e-3)
    # plt.scatter([20],[2*(i-6)])

# plt.xlim([0,10])
# plt.ylim([1e-1,5])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
plt.yscale('log')
plt.tight_layout()

# %% [markdown]
# ### TwoClifB

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(152,157):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[1:,0],raw[1:,1]+1e-3)
    # plt.scatter([20],[2*(i-6)])

# plt.xlim([0,10])
# plt.ylim([1e-1,5])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
plt.yscale('log')
plt.tight_layout()

# %% [markdown]
# ### TwoClif

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(157,162):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[1:,0],raw[1:,1]+1e-3)
    raw = np.loadtxt("data/230213/230213_%d"%(i-155),delimiter=',',skiprows=1)
    plt.scatter(raw[1:,0],raw[1:,1]+1e-3)
    raw = np.loadtxt("data/230213/230213_%d"%(i-5),delimiter=',',skiprows=1)
    plt.plot(raw[1:,0],raw[1:,1]+1e-3,"--",color="grey")
    # plt.scatter([20],[2*(i-6)])

plt.xlim([0,100])
# plt.ylim([1e-1,5])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
plt.yscale('log')
plt.tight_layout()

# %% [markdown]
# ### BW

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(1,3):
    raw = np.loadtxt("data/230225/230225_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[1:,0],raw[1:,1]+1e-3)

# plt.xlim([0,100])
# plt.ylim([1e-1,5])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(3,8):
    raw = np.loadtxt("data/230225/230225_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3)

# plt.xlim([0,100])
# plt.ylim([1e-1,5])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
plt.yscale('log')
plt.tight_layout()

# %% [markdown]
# ### HPBBW

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(8,12):
    raw = np.loadtxt("data/230225/230225_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[1:,0],raw[1:,1]+1e-3)

# plt.xlim([0,100])
# plt.ylim([1e-1,5])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(12,17):
    raw = np.loadtxt("data/230225/230225_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3)

# plt.xlim([0,100])
# plt.ylim([1e-1,5])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
# plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(17,22):
    raw = np.loadtxt("data/230225/230225_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3)

# plt.xlim([0,100])
# plt.ylim([1e-1,5])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
# plt.yscale('log')
plt.tight_layout()

# %% [markdown]
# ### BW Nmeas Depth

# %%
file_name = "data/230226/230226_nd1_pp.npz"

raw = np.load(file_name)
n_meas_l  = raw['n_meas_l']
depth_l  = raw['depth_l']
cmi_ave_l = raw['cmi_ave_l']
cmi_std_l = raw['cmi_std_l']

plt.rcParams["figure.figsize"] = (6,5)
plt.imshow(cmi_ave_l,extent=[n_meas_l[0],n_meas_l[-1],depth_l[-1],depth_l[0]])
plt.xlim([50,100])
plt.xlabel("# measurements")
plt.ylabel("circuit depth")
plt.tight_layout()

# %%
for i in range(0,30,1):
    plt.plot(n_meas_l,cmi_ave_l[i,:])
# plt.yscale('log')

plt.rcParams["figure.figsize"] = (6,5)
plt.xlim([50,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
# plt.plot(cmi_ave_l[:, 0])

for i in range(35,49):
    plt.plot(depth_l,cmi_ave_l[:,i])
plt.rcParams["figure.figsize"] = (6,5)
plt.xlim([0,60])
plt.xlabel("circuit depth")
plt.ylabel("MIE")
plt.tight_layout()

# %%
file_name = "data/230305/230305_nd1_pp.npz"

raw = np.load(file_name)
n_meas_l  = raw['n_meas_l']
depth_l  = raw['depth_l']
cmi_ave_l = raw['cmi_ave_l']
cmi_std_l = raw['cmi_std_l']

plt.imshow(cmi_ave_l)

# %%
for i in range(0,50,1):
    plt.plot(n_meas_l,cmi_ave_l[i,:])
plt.yscale('log')
plt.xlim([50,100])
# Out:
# (50.0, 100.0)

# %%
# plt.plot(cmi_ave_l[:, 0])

for i in range(0,25):
    plt.plot(depth_l,cmi_ave_l[:,i])
# plt.yscale('log')

# %%
file_name = "../data/230305/230305_nd3_pp.npz"

raw = np.load(file_name)
n_meas_l  = raw['n_meas_l']
depth_l  = raw['depth_l']
cmi_ave_l = raw['cmi_ave_l']
cmi_std_l = raw['cmi_std_l']

plt.rcParams.update({'font.size': 25})
plt.figure(figsize=(6,5))
plt.imshow(cmi_ave_l[::-1,:],cmap='Oranges',aspect='auto',extent=[50,100,0,50])
plt.xticks([50,60,70,80,90,100])
plt.xlabel("# measurements")
plt.ylabel("depth")
plt.colorbar()

# %%
plt.rcParams["figure.figsize"] = (12,5)
ax = plt.subplot()
cmap = mpl.colormaps['winter']

for i in range(0,50,2):
    plt.subplot(1,2,1)
    plt.plot(n_meas_l,cmi_ave_l[i,:],c=cmap((i)/50))
    plt.subplot(1,2,2)
    plt.plot(n_meas_l,cmi_ave_l[i,:],c=cmap((i)/50))
plt.subplot(1,2,1)
plt.xlim([50,100])
plt.xlabel('# measurements')
plt.ylabel('$I_T$')
plt.subplot(1,2,2)
plt.yscale('log')
plt.xlim([50,100])
plt.xlabel('# measurements')
plt.ylabel('$I_T$')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (5,5)
ax = plt.subplot()
cmap = mpl.colormaps['Greens']

for i in range(0,25):
    plt.plot(depth_l,cmi_ave_l[:,i],c=cmap((i-0)/25))
# plt.yscale('log')
plt.xlim([0,100])
# Out:
# (0.0, 100.0)

# %%
for i in range(0,50,1):
    plt.plot(n_meas_l,cmi_ave_l[i,:])
plt.yscale('log')
plt.xlim([30,100])
# Out:
# (30.0, 100.0)

# %%
# plt.plot(cmi_ave_l[:, 0])

for i in range(0,25):
    plt.plot(depth_l,cmi_ave_l[:,i])
# plt.yscale('log')

# %%
file_name = "data/230305/230305_nd4_pp.npz"

raw = np.load(file_name)
n_meas_l  = raw['n_meas_l']
depth_l  = raw['depth_l']
cmi_ave_l = raw['cmi_ave_l']
cmi_std_l = raw['cmi_std_l']

plt.imshow(cmi_ave_l)

# %%
for i in range(0,30,1):
    plt.plot(n_meas_l,cmi_ave_l[i,:])
plt.yscale('log')
plt.xlim([20,60])
# Out:
# (20.0, 60.0)

# %%
# plt.plot(cmi_ave_l[:, 0])

for i in range(0,15):
    plt.plot(depth_l,cmi_ave_l[:,i])
# plt.yscale('log')

# %% [markdown]
# ### HPBBW Nmeas Depth

# %%
file_name = "data/230226/230226_nd2_pp.npz"

raw = np.load(file_name)
n_meas_l  = raw['n_meas_l']
depth_l  = raw['depth_l']
cmi_ave_l = raw['cmi_ave_l']
cmi_std_l = raw['cmi_std_l']

plt.imshow(cmi_ave_l)

# %%
for i in range(0,20,2):
    plt.plot(depth_l,cmi_ave_l[:,i])

# %%
for i in range(0,60,4):
    plt.plot(n_meas_l,cmi_ave_l[i,:])

# %%
file_name = "data/230226/230226_nd2_pp.npz"

raw = np.load(file_name)
n_meas_l  = raw['n_meas_l']
depth_l  = raw['depth_l']
cmi_ave_l = raw['cmi_ave_l']
cmi_std_l = raw['cmi_std_l']

plt.imshow(np.diff(cmi_ave_l,axis=1))

# %%
for i in range(0,60,4):
    plt.plot(n_meas_l[0:-1],np.diff(cmi_ave_l,axis=1)[i,:])

# %%
file_name = "data/230305/230305_nd8_pp.npz"

raw = np.load(file_name)
n_meas_l  = raw['n_meas_l']
depth_l  = raw['depth_l']
cmi_ave_l = raw['cmi_ave_l']
cmi_std_l = raw['cmi_std_l']

plt.rcParams["figure.figsize"] = (6,5)
plt.imshow(cmi_ave_l,extent=[n_meas_l[0],n_meas_l[-1],depth_l[-1],depth_l[0]],aspect='auto')
# plt.xlim([50,100])
plt.xlabel("# measurements")
plt.ylabel("circuit depth")
plt.tight_layout()

# %%
for i in range(0,50,2):
    plt.plot(depth_l,cmi_ave_l[:,i])

plt.xlim([0,100])
plt.xlabel("circuit depth")
plt.ylabel("MIE")
plt.tight_layout()

# %%
for i in range(0,50,4):
    plt.plot(n_meas_l,cmi_ave_l[i,:])

plt.xlim([0,200])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %% [markdown]
# ### HPBW Nmeas Depth

# %%
file_name = "data/230226/230226_nd3_pp.npz"

raw = np.load(file_name)
n_meas_l  = raw['n_meas_l']
depth_l  = raw['depth_l']
cmi_ave_l = raw['cmi_ave_l']
cmi_std_l = raw['cmi_std_l']

plt.rcParams["figure.figsize"] = (6,5)
plt.imshow(cmi_ave_l,extent=[n_meas_l[0],n_meas_l[-1],depth_l[-1],depth_l[0]],aspect='auto')
plt.imshow(np.diff(cmi_ave_l,axis=0),extent=[n_meas_l[0],n_meas_l[-1],depth_l[-1],depth_l[0]],aspect='auto')
# plt.xlim([50,100])
plt.xlabel("# measurements")
plt.ylabel("circuit depth")
plt.tight_layout()

# %%
for i in range(0,49,4):
    plt.plot(depth_l,cmi_ave_l[:,i])

plt.xlim([0,120])
plt.xlabel("circuit depth")
plt.ylabel("MIE")
plt.tight_layout()

# %%
for i in range(0,59,5):
    plt.plot(n_meas_l,cmi_ave_l[i,:])

plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
file_name = "data/230301/230301_nd3_pp.npz"

raw = np.load(file_name)
n_meas_l  = raw['n_meas_l']
depth_l  = raw['depth_l']
cmi_ave_l = raw['cmi_ave_l']
cmi_std_l = raw['cmi_std_l']

plt.imshow(cmi_ave_l)

# %%
for i in range(0,49,4):
    plt.plot(depth_l,cmi_ave_l[:,i])

# plt.xlim([0,20])
# plt.ylim([0,10])
# plt.yscale("log")

# %%
for i in range(0,49,4):
    plt.plot(depth_l,np.diff(cmi_ave_l[:,i],prepend=[0]))

# plt.xlim([0,20])
# plt.ylim([0,10])
# plt.yscale("log")

# %%
for i in range(0,59,5):
    plt.plot(n_meas_l,cmi_ave_l[i,:])

# plt.yscale('log')

# %% [markdown]
# ### TMB

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(1,6):
    raw = np.loadtxt("data/230226/230226_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3)

# plt.xlim([0,100])
# plt.ylim([1e-1,5])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(6,11):
    raw = np.loadtxt("data/230226/230226_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3)

# plt.xlim([0,100])
# plt.ylim([1e-1,5])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
# plt.yscale('log')
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)

for i in range(12,17):
    raw = np.loadtxt("data/230226/230226_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3)

for i in range(18,23):
    raw = np.loadtxt("data/230213/230213_%d"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3,'b')
    raw = np.loadtxt("data/230213/230213_%d"%(i-16),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1]+1e-3,'m')
    
# plt.xlim([0,100])
# plt.ylim([1e-1,5])
plt.xlabel("number of measurements")
plt.ylabel("MIE")
plt.yscale('log')
plt.tight_layout()
